# %%
from llama_index.core import Settings, SimpleDirectoryReader, VectorStoreIndex, load_index_from_storage
from llama_index.agent.lats import LATSAgentWorker
from llama_index.core.agent import AgentRunner
from llama_index.llms.ollama import Ollama
from llama_index.llms.openai_like import OpenAILike
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.embeddings.ollama import OllamaEmbedding
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.storage import StorageContext
import os

# %%
import nest_asyncio 
nest_asyncio.apply()

# %%
# llm = OpenAILike(
#     api_base="http://localhost:11434/v1",
#     model="mistral-small",
#     api_key="fake"
#     )
# llm = Ollama(model="llama3.1") # llama3.1 is not working
llm = Ollama(model="qwen2.5") # qwen2.5 is good for this task
# llm = Ollama(model="mistral-small", request_timeout=300)

embed_model = OllamaEmbedding("nomic-embed-text:latest")
# embed_model = HuggingFaceEmbedding("BAAI/bge-base-en-v1.5")

Settings.llm = llm
Settings.embed_model = embed_model

# %%
if not os.path.exists("/home/forrest/Github/learn_llamaindex/data/storage/lyft"):
    # load data
    lyft_docs = SimpleDirectoryReader(
        input_files=["/home/forrest/Github/learn_llamaindex/data/10k/lyft_2021.pdf"]
    ).load_data()
    uber_docs = SimpleDirectoryReader(
        input_files=["/home/forrest/Github/learn_llamaindex/data/10k/uber_2021.pdf"]
    ).load_data()

    # build index
    lyft_index = VectorStoreIndex.from_documents(lyft_docs)
    uber_index = VectorStoreIndex.from_documents(uber_docs)

    # persist index
    lyft_index.storage_context.persist(persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/lyft")
    uber_index.storage_context.persist(persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/uber")
else:
    storage_context = StorageContext.from_defaults(
        persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/lyft"
    )
    lyft_index = load_index_from_storage(storage_context)

    storage_context = StorageContext.from_defaults(
        persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/uber"
    )
    uber_index = load_index_from_storage(storage_context)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/utils.py:118, in _issubclass_safe(cls, classinfo)
#     117 try:
# --> 118     return issubclass(cls, classinfo)
#     119 except Exception:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/typing.py:498, in _SpecialForm.__subclasscheck__(self, cls)
#     497 def __subclasscheck__(self, cls):
# --> 498     raise TypeError(f"{self} cannot be used with issubclass()")
#
# TypeError: typing.Optional cannot be used with issubclass()
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 18
#      16     uber_index.storage_context.persist(persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/uber")
#      17 else:
# ---> 18     storage_context = StorageContext.from_defaults(
#      19         persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/lyft"
#      20     )
#      21     lyft_index = load_index_from_storage(storage_context)
#      23     storage_context = StorageContext.from_defaults(
#      24         persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/uber"
#      25     )
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/storage/storage_context.py:134, in StorageContext.from_defaults(cls, docstore, index_store, vector_store, image_store, vector_stores, graph_store, property_graph_store, persist_dir, fs)
#     132     vector_stores = vector_stores
#     133 else:
# --> 134     vector_stores = SimpleVectorStore.from_namespaced_persist_dir(
#     135         persist_dir, fs=fs
#     136     )
#     137 if image_store:
#     138     # append image store to vector stores
#     139     vector_stores[IMAGE_VECTOR_STORE_NAMESPACE] = image_store  # type: ignore
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/vector_stores/simple.py:203, in SimpleVectorStore.from_namespaced_persist_dir(cls, persist_dir, fs)
#     199                 vector_stores[DEFAULT_VECTOR_STORE] = cls.from_persist_dir(
#     200                     persist_dir=persist_dir, fs=fs
#     201                 )
#     202             else:
# --> 203                 vector_stores[namespace] = cls.from_persist_dir(
#     204                     persist_dir=persist_dir, namespace=namespace, fs=fs
#     205                 )
#     206 except Exception:
#     207     # failed to listdir, so assume there is only one store
#     208     try:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/vector_stores/simple.py:179, in SimpleVectorStore.from_persist_dir(cls, persist_dir, namespace, fs)
#     177 else:
#     178     persist_path = os.path.join(persist_dir, persist_fname)
# --> 179 return cls.from_persist_path(persist_path, fs=fs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/vector_stores/simple.py:415, in SimpleVectorStore.from_persist_path(cls, persist_path, fs)
#     413 with fs.open(persist_path, "rb") as f:
#     414     data_dict = json.load(f)
# --> 415     data = SimpleVectorStoreData.from_dict(data_dict)
#     416 return cls(data)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/api.py:70, in DataClassJsonMixin.from_dict(cls, kvs, infer_missing)
#      65 @classmethod
#      66 def from_dict(cls: Type[A],
#      67               kvs: Json,
#      68               *,
#      69               infer_missing=False) -> A:
# ---> 70     return _decode_dataclass(cls, kvs, infer_missing)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:233, in _decode_dataclass(cls, kvs, infer_missing)
#     231     init_kwargs[field.name] = value
#     232 elif _is_supported_generic(field_type) and field_type != str:
# --> 233     init_kwargs[field.name] = _decode_generic(field_type,
#     234                                               field_value,
#     235                                               infer_missing)
#     236 else:
#     237     init_kwargs[field.name] = _support_extended_types(field_type,
#     238                                                       field_value)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:304, in _decode_generic(type_, value, infer_missing)
#     301     # a mapping type has `.keys()` and `.values()`
#     302     # (see collections.abc)
#     303     ks = _decode_dict_keys(k_type, value.keys(), infer_missing)
# --> 304     vs = _decode_items(v_type, value.values(), infer_missing)
#     305     xs = zip(ks, vs)
#     306 elif _is_tuple(type_):
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:410, in _decode_items(type_args, xs, infer_missing)
#     405     else:
#     406         raise TypeError(f"Number of types specified in the collection type {str(type_args)} "
#     407                         f"does not match number of elements in the collection. In case you are working with tuples"
#     408                         f"take a look at this document "
#     409                         f"docs.python.org/3/library/typing.html#annotating-tuples.")
# --> 410 return list(_decode_type(type_args, x, infer_missing) for x in xs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:410, in <genexpr>(.0)
#     405     else:
#     406         raise TypeError(f"Number of types specified in the collection type {str(type_args)} "
#     407                         f"does not match number of elements in the collection. In case you are working with tuples"
#     408                         f"take a look at this document "
#     409                         f"docs.python.org/3/library/typing.html#annotating-tuples.")
# --> 410 return list(_decode_type(type_args, x, infer_missing) for x in xs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:247, in _decode_type(type_, value, infer_missing)
#     245     return _get_decoder_in_global_config(type_)(value)
#     246 if _is_supported_generic(type_):
# --> 247     return _decode_generic(type_, value, infer_missing)
#     248 if is_dataclass(type_) or is_dataclass(value):
#     249     return _decode_dataclass(type_, value, infer_missing)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:315, in _decode_generic(type_, value, infer_missing)
#     313     xs = dict(zip(_decode_items(_get_type_arg_param(type_, 0), value.keys(), infer_missing), value.values()))
#     314 else:
# --> 315     xs = _decode_items(_get_type_arg_param(type_, 0), value, infer_missing)
#     317 collection_type = _resolve_collection_type_to_decode_to(type_)
#     318 res = collection_type(xs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:410, in _decode_items(type_args, xs, infer_missing)
#     405     else:
#     406         raise TypeError(f"Number of types specified in the collection type {str(type_args)} "
#     407                         f"does not match number of elements in the collection. In case you are working with tuples"
#     408                         f"take a look at this document "
#     409                         f"docs.python.org/3/library/typing.html#annotating-tuples.")
# --> 410 return list(_decode_type(type_args, x, infer_missing) for x in xs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:410, in <genexpr>(.0)
#     405     else:
#     406         raise TypeError(f"Number of types specified in the collection type {str(type_args)} "
#     407                         f"does not match number of elements in the collection. In case you are working with tuples"
#     408                         f"take a look at this document "
#     409                         f"docs.python.org/3/library/typing.html#annotating-tuples.")
# --> 410 return list(_decode_type(type_args, x, infer_missing) for x in xs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:246, in _decode_type(type_, value, infer_missing)
#     244 if _has_decoder_in_global_config(type_):
#     245     return _get_decoder_in_global_config(type_)(value)
# --> 246 if _is_supported_generic(type_):
#     247     return _decode_generic(type_, value, infer_missing)
#     248 if is_dataclass(type_) or is_dataclass(value):
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/core.py:286, in _is_supported_generic(type_)
#     284 is_enum = _issubclass_safe(type_, Enum)
#     285 is_generic_dataclass = _is_generic_dataclass(type_)
# --> 286 return (not_str and _is_collection(type_)) or _is_optional(
#     287     type_) or is_union_type(type_) or is_enum or is_generic_dataclass
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/utils.py:142, in _is_optional(type_)
#     141 def _is_optional(type_):
# --> 142     return (_issubclass_safe(type_, Optional) or
#     143             _hasargs(type_, type(None)) or
#     144             type_ is Any)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/utils.py:121, in _issubclass_safe(cls, classinfo)
#     118     return issubclass(cls, classinfo)
#     119 except Exception:
#     120     return (_is_new_type_subclass_safe(cls, classinfo)
# --> 121             if _is_new_type(cls)
#     122             else False)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/dataclasses_json/utils.py:137, in _is_new_type(type_)
#     133     except Exception:
#     134         return False
# --> 137 def _is_new_type(type_):
#     138     return inspect.isfunction(type_) and hasattr(type_, "__supertype__")
#     141 def _is_optional(type_):
#
# KeyboardInterrupt:

# %%
# uber_docs=SimpleDirectoryReader(input_files=['/home/forrest/Github/learn_llamaindex/data/UBER/uber_2021.pdf']).load_data()

# uber_index = VectorStoreIndex.from_documents(uber_docs)

# uber_index.storage_context.persist(persist_dir="/home/forrest/Github/learn_llamaindex/data/storage/uber")
lyft_engine = lyft_index.as_query_engine(similarity_top_k=3)
uber_engine = uber_index.as_query_engine(similarity_top_k=3)

# %%
uber_engine.query("What is the mission of Uber?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 uber_engine.query("What is the mission of Uber?")
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/base/base_query_engine.py:52, in BaseQueryEngine.query(self, str_or_query_bundle)
#      50     if isinstance(str_or_query_bundle, str):
#      51         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 52     query_result = self._query(str_or_query_bundle)
#      53 dispatcher.event(
#      54     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      55 )
#      56 return query_result
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/query_engine/retriever_query_engine.py:178, in RetrieverQueryEngine._query(self, query_bundle)
#     174 with self.callback_manager.event(
#     175     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     176 ) as query_event:
#     177     nodes = self.retrieve(query_bundle)
# --> 178     response = self._response_synthesizer.synthesize(
#     179         query=query_bundle,
#     180         nodes=nodes,
#     181     )
#     182     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     184 return response
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/response_synthesizers/base.py:241, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     235     query = QueryBundle(query_str=query)
#     237 with self._callback_manager.event(
#     238     CBEventType.SYNTHESIZE,
#     239     payload={EventPayload.QUERY_STR: query.query_str},
#     240 ) as event:
# --> 241     response_str = self.get_response(
#     242         query_str=query.query_str,
#     243         text_chunks=[
#     244             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     245         ],
#     246         **response_kwargs,
#     247     )
#     249     additional_source_nodes = additional_source_nodes or []
#     250     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/response_synthesizers/compact_and_refine.py:43, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      39 # use prompt helper to fix compact text_chunks under the prompt limitation
#      40 # TODO: This is a temporary fix - reason it's temporary is that
#      41 # the refine template does not account for size of previous answer.
#      42 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43 return super().get_response(
#      44     query_str=query_str,
#      45     text_chunks=new_texts,
#      46     prev_response=prev_response,
#      47     **response_kwargs,
#      48 )
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/response_synthesizers/refine.py:177, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     173 for text_chunk in text_chunks:
#     174     if prev_response is None:
#     175         # if this is the first chunk, and text chunk already
#     176         # is an answer, then return it
# --> 177         response = self._give_response_single(
#     178             query_str, text_chunk, **response_kwargs
#     179         )
#     180     else:
#     181         # refine response if possible
#     182         response = self._refine_response_single(
#     183             prev_response, query_str, text_chunk, **response_kwargs
#     184         )
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/response_synthesizers/refine.py:234, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     230 if response is None and not self._streaming:
#     231     try:
#     232         structured_response = cast(
#     233             StructuredRefineResponse,
# --> 234             program(
#     235                 context_str=cur_text_chunk,
#     236                 **response_kwargs,
#     237             ),
#     238         )
#     239         query_satisfied = structured_response.query_satisfied
#     240         if query_satisfied:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/response_synthesizers/refine.py:84, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      82     answer = answer.model_dump_json()
#      83 else:
# ---> 84     answer = self._llm.predict(
#      85         self._prompt,
#      86         **kwds,
#      87     )
#      88 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/llms/llm.py:578, in LLM.predict(self, prompt, **prompt_args)
#     576 if self.metadata.is_chat_model:
#     577     messages = self._get_messages(prompt, **prompt_args)
# --> 578     chat_response = self.chat(messages)
#     579     output = chat_response.message.content or ""
#     580 else:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/llms/callbacks.py:173, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     164 event_id = callback_manager.on_event_start(
#     165     CBEventType.LLM,
#     166     payload={
#    (...)
#     170     },
#     171 )
#     172 try:
# --> 173     f_return_val = f(_self, messages, **kwargs)
#     174 except BaseException as e:
#     175     callback_manager.on_event_end(
#     176         CBEventType.LLM,
#     177         payload={EventPayload.EXCEPTION: e},
#     178         event_id=event_id,
#     179     )
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/llms/ollama/base.py:275, in Ollama.chat(self, messages, **kwargs)
#     271 ollama_messages = self._convert_to_ollama_messages(messages)
#     273 tools = kwargs.pop("tools", None)
# --> 275 response = self.client.chat(
#     276     model=self.model,
#     277     messages=ollama_messages,
#     278     stream=False,
#     279     format="json" if self.json_mode else "",
#     280     tools=tools,
#     281     options=self._model_kwargs,
#     282 )
#     284 tool_calls = response["message"].get("tool_calls", [])
#     285 token_counts = self._get_response_token_counts(response)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/ollama/_client.py:235, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     232   if images := message.get('images'):
#     233     message['images'] = [_encode_image(image) for image in images]
# --> 235 return self._request_stream(
#     236   'POST',
#     237   '/api/chat',
#     238   json={
#     239     'model': model,
#     240     'messages': messages,
#     241     'tools': tools or [],
#     242     'stream': stream,
#     243     'format': format,
#     244     'options': options or {},
#     245     'keep_alive': keep_alive,
#     246   },
#     247   stream=stream,
#     248 )
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/ollama/_client.py:98, in Client._request_stream(self, stream, *args, **kwargs)
#      92 def _request_stream(
#      93   self,
#      94   *args,
#      95   stream: bool = False,
#      96   **kwargs,
#      97 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 98   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/ollama/_client.py:69, in Client._request(self, method, url, **kwargs)
#      68 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 69   response = self._client.request(method, url, **kwargs)
#      71   try:
#      72     response.raise_for_status()
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=lyft_engine,
        metadata=ToolMetadata(
            name="lyft_10k",
            description=(
                "Provides information about Lyft financials for year 2021. "
                "Use a detailed plain text question as input to the tool. "
                "The input is used to power a semantic search engine."
            ),
        ),
    ),
    QueryEngineTool(
        query_engine=uber_engine,
        metadata=ToolMetadata(
            name="uber_10k",
            description=(
                "Provides information about Uber financials for year 2021. "
                "Use a detailed plain text question as input to the tool. "
                "The input is used to power a semantic search engine."
            ),
        ),
    ),
]

# %%
# query_engine_tools.pop(0)

# %%
agent_worker = LATSAgentWorker.from_tools(
    query_engine_tools,
    llm=llm,
    num_expansions=2,
    max_rollouts=5,  # using -1 for unlimited rollouts
    verbose=True,
)
agent = AgentRunner(agent_worker)

# %%
task = agent.create_task(
    "Given the risk factors Uber described in their 10K files, "
    "what are the most important factors to consider for investing in Uber?"
)

# %%
step_output = agent.run_step(task.task_id)
# step_output_dict = step_output.dict() if hasattr(step_output, 'dict') else step_output
# agent.chat( "Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?")
# Out:
# > Selecting node to expand: Observation: Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?
# > Got candidates: ['Regulatory risks and compliance issues', 'Rider and driver safety concerns']
# === Calling Function ===
# Calling function: uber_10k with args: {"input": "What are the most important risk factors for investing in Uber based on their 2021 10-K filing?"}
# === Calling Function ===
# Calling function: uber_10k with args: {"input": "Discuss regulatory risks and compliance issues in detail as mentioned in Uber's 2021 10-K."}
# === Function Output ===
# Based on the 2021 10-K filing, some of the most important risk factors for investing in Uber include:
#
# - The potential impact of Driver misclassification challenges. If Drivers were classified as employees or quasi-employees instead of independent contractors, it could significantly affect Uber's financial statements and operations.
# - Increased operating expenses, which may not be offset by corresponding increases in revenue.
# - Challenges in maintaining a critical mass of users across various categories such as Drivers, consumers, merchants, shippers, and carriers. Losing any one group could diminish the overall appeal of the platform.
# - Risks associated with criminal activities or negative safety incidents involving platform users, which can harm Uber's brand and reputation.
# - The inherent risks involved in new investments and technological advancements, where expected benefits might not materialize.
# - Economic, social, weather, and regulatory conditions that may negatively impact operations in large metropolitan areas.
#
# These factors highlight the operational, financial, and reputational challenges that could affect Uber's business performance and profitability.
# === Function Output ===
# Regulatory risks and compliance issues are significant for Uber, as detailed in their 2021 10-K. Substantially all states in the United States and numerous municipalities have adopted regulations concerning Transportation Network Companies (TNCs). These regulations typically encompass a wide range of requirements such as background checks, vehicle inspections, accessible vehicles, driver safety, insurance, training, conduct, and more.
#
# One notable aspect is California's Assembly Bill 5 (AB5), which took effect in January 2020. This legislation introduced a test to determine worker classification under California law. The California Attorney General and city attorneys for San Francisco, Los Angeles, and San Diego filed a complaint alleging that Uber drivers were misclassified as independent contractors rather than employees. Despite the court issuing a preliminary injunction preventing such classifications during the lawsuit's pendency, the parties agreed in April 2021 to dissolve this injunction. In November 2020, California voters approved Proposition 22, which provides a framework for drivers who use platforms like Uber’s as independent contractors.
#
# Apart from these specific cases, the general regulatory environment is complex and fragmented, creating significant complexities for Uber's business operations and model. These regulations can affect various aspects of their service delivery and operational costs, potentially impacting profitability and financial performance.
#
# In summary, the diverse array of TNC regulations across different jurisdictions presents both challenges and opportunities for Uber, necessitating careful compliance to avoid legal issues and maintain operational integrity.
# > Generated new reasoning step: Thought: I need more detailed information about regulatory risks and compliance issues mentioned in Uber's 10K report to properly identify the most important factors for investors. I will use the `uber_10k` tool to get this information.
# Action: uber_10k
# Action Input: {'input': "Discuss regulatory risks and compliance issues in detail as mentioned in Uber's 2021 10-K."}
# Observation: Regulatory risks and compliance issues are significant for Uber, as detailed in their 2021 10-K. Substantially all states in the United States and numerous municipalities have adopted regulations concerning Transportation Network Companies (TNCs). These regulations typically encompass a wide range of requirements such as background checks, vehicle inspections, accessible vehicles, driver safety, insurance, training, conduct, and more.
#
# One notable aspect is California's Assembly Bill 5 (AB5), which took effect in January 2020. This legislation introduced a test to determine worker classification under California law. The California Attorney General and city attorneys for San Francisco, Los Angeles, and San Diego filed a complaint alleging that Uber drivers were misclassified as independent contractors rather than employees. Despite the court issuing a preliminary injunction preventing such classifications during the lawsuit's pendency, the parties agreed in April 2021 to dissolve this injunction. In November 2020, California voters approved Proposition 22, which provides a framework for drivers who use platforms like Uber’s as independent contractors.
#
# Apart from these specific cases, the general regulatory environment is complex and fragmented, creating significant complexities for Uber's business operations and model. These regulations can affect various aspects of their service delivery and operational costs, potentially impacting profitability and financial performance.
#
# In summary, the diverse array of TNC regulations across different jurisdictions presents both challenges and opportunities for Uber, necessitating careful compliance to avoid legal issues and maintain operational integrity.
# > Generated new reasoning step: Thought: I need more detailed information about the specific risk factors mentioned in Uber's 10K file. I should use the uber_10k tool to get this information.
# Action: uber_10k
# Action Input: {'input': 'What are the most important risk factors for investing in Uber based on their 2021 10-K filing?'}
# Observation: Based on the 2021 10-K filing, some of the most important risk factors for investing in Uber include:
#
# - The potential impact of Driver misclassification challenges. If Drivers were classified as employees or quasi-employees instead of independent contractors, it could significantly affect Uber's financial statements and operations.
# - Increased operating expenses, which may not be offset by corresponding increases in revenue.
# - Challenges in maintaining a critical mass of users across various categories such as Drivers, consumers, merchants, shippers, and carriers. Losing any one group could diminish the overall appeal of the platform.
# - Risks associated with criminal activities or negative safety incidents involving platform users, which can harm Uber's brand and reputation.
# - The inherent risks involved in new investments and technological advancements, where expected benefits might not materialize.
# - Economic, social, weather, and regulatory conditions that may negatively impact operations in large metropolitan areas.
#
# These factors highlight the operational, financial, and reputational challenges that could affect Uber's business performance and profitability.
# > Evaluation for input Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?
# : score=8 is_done=False reasoning='The latest thoughts and actions in the conversation are on the right track. The discussion of regulatory risks and compliance issues is relevant to the query about investing in Uber. However, the analysis does not yet directly identify which factors are most important for investors. More specific insights related to investor considerations (e.g., financial impact, long-term implications) would help determine the most critical factors.'
#
# > Evaluation for input Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?
# : score=9 is_done=False reasoning="The latest thoughts and actions in this trajectory are highly relevant to the query. The conversation has moved from general rider and driver safety concerns to specific risk factors mentioned in Uber's 2021 10-K filing, which directly address what investors should consider when investing in Uber. However, the completeness is not yet achieved because the answer is still not found as the trajectory does not conclude by explicitly stating that these are the most important factors for investment. The trajectory provides a detailed list of risk factors but lacks a clear conclusion or confirmation that they are indeed the 'most' important."
#
# > Got final response: I am still thinking.

# %%
for step in (
    step_output.task_step.step_state["root_node"].children[0].current_reasoning
):
    print(step)
    print("---------")
# Out:
# observation='Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?' return_direct=False
# ---------
# observation='Regulatory risks and compliance issues' return_direct=False
# ---------

# %%
for step in (
    step_output.task_step.step_state["root_node"]
    .children[0]
    .children[0]
    .current_reasoning
):
    print(step)
    print("---------")
# Out:
# observation='Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?' return_direct=False
# ---------
# observation='Regulatory risks and compliance issues' return_direct=False
# ---------
# thought="I need more detailed information about regulatory risks and compliance issues mentioned in Uber's 10K report to properly identify the most important factors for investors. I will use the `uber_10k` tool to get this information." action='uber_10k' action_input={'input': "Discuss regulatory risks and compliance issues in detail as mentioned in Uber's 2021 10-K."}
# ---------
# observation="Regulatory risks and compliance issues are significant for Uber, as detailed in their 2021 10-K. Substantially all states in the United States and numerous municipalities have adopted regulations concerning Transportation Network Companies (TNCs). These regulations typically encompass a wide range of requirements such as background checks, vehicle inspections, accessible vehicles, driver safety, insurance, training, conduct, and more.\n\nOne notable aspect is California's Assembly Bill 5 (AB5), which took effect in January 2020. This legislation introduced a test to determine worker classification under California law. The California Attorney General and city attorneys for San Francisco, Los Angeles, and San Diego filed a complaint alleging that Uber drivers were misclassified as independent contractors rather than employees. Despite the court issuing a preliminary injunction preventing such classifications during the lawsuit's pendency, the parties agreed in April 2021 to dissolve this injunction. In November 2020, California voters approved Proposition 22, which provides a framework for drivers who use platforms like Uber’s as independent contractors.\n\nApart from these specific cases, the general regulatory environment is complex and fragmented, creating significant complexities for Uber's business operations and model. These regulations can affect various aspects of their service delivery and operational costs, potentially impacting profitability and financial performance.\n\nIn summary, the diverse array of TNC regulations across different jurisdictions presents both challenges and opportunities for Uber, necessitating careful compliance to avoid legal issues and maintain operational integrity." return_direct=False
# ---------

# %%
while not step_output.is_last:
    step_output = agent.run_step(task.task_id)

response = agent.finalize_response(task.task_id)
# Out:
# > Selecting node to expand: Observation: Based on the 2021 10-K filing, some of the most important risk factors for investing in Uber include:
#
# - The potential impact of Driver misclassification challenges. If Drivers were classified as employees or quasi-employees instead of independent contractors, it could significantly affect Uber's financial statements and operations.
# - Increased operating expenses, which may not be offset by corresponding increases in revenue.
# - Challenges in maintaining a critical mass of users across various categories such as Drivers, consumers, merchants, shippers, and carriers. Losing any one group could diminish the overall appeal of the platform.
# - Risks associated with criminal activities or negative safety incidents involving platform users, which can harm Uber's brand and reputation.
# - The inherent risks involved in new investments and technological advancements, where expected benefits might not materialize.
# - Economic, social, weather, and regulatory conditions that may negatively impact operations in large metropolitan areas.
#
# These factors highlight the operational, financial, and reputational challenges that could affect Uber's business performance and profitability.
# > Got candidates: ['The potential impact of Driver misclassification challenges.', 'Increased operating expenses, which may not be offset by corresponding increases in revenue.']
# === Calling Function ===
# Calling function: uber_10k with args: {"input": "What specific risks related to rider and driver safety are mentioned in Uber's 2021 10-K filing?"}
# === Function Output ===
# The specific risks related to rider and driver safety mentioned in Uber's 2021 10-K filing include regulatory requirements that focus on companies like TNCs, which connect individual drivers with their own vehicles to passengers. These regulations often require compliance with rules such as background checks, vehicle inspections, accessible vehicle standards, driver and consumer safety measures, insurance provisions, driver training, and driver conduct. While the context does not explicitly mention these regulatory requirements under the risk factors section, it highlights that these are significant complexities for Uber's business due to the adoption of various TNC regulations in different jurisdictions.
# > Generated new reasoning step: Thought: I can answer without using any more tools. I'll use the user's language to answer.
# Answer: Based on the 2021 10-K filing, some of the most important risk factors for investing in Uber include:
#
# - The potential impact of Driver misclassification challenges: If Drivers were classified as employees or quasi-employees instead of independent contractors, it could significantly affect Uber's financial statements and operations.
# - Increased operating expenses that may not be offset by corresponding increases in revenue.
# - Challenges in maintaining a critical mass of users across various categories such as Drivers, consumers, merchants, shippers, and carriers. Losing any one group could diminish the overall appeal of the platform.
# - Risks associated with criminal activities or negative safety incidents involving platform users, which can harm Uber's brand and reputation.
# - The inherent risks involved in new investments and technological advancements where expected benefits might not materialize.
# - Economic, social, weather, and regulatory conditions that may negatively impact operations in large metropolitan areas.
#
# These factors highlight the operational, financial, and reputational challenges that could affect Uber's business performance and profitability.
# > Generated new reasoning step: Thought: The information provided from the 10-K filing highlights several critical risk factors for investing in Uber. However, I need to further focus on the specific concern about rider and driver safety concerns that were mentioned earlier.
# Action: uber_10k
# Action Input: {'input': "What specific risks related to rider and driver safety are mentioned in Uber's 2021 10-K filing?"}
# Observation: The specific risks related to rider and driver safety mentioned in Uber's 2021 10-K filing include regulatory requirements that focus on companies like TNCs, which connect individual drivers with their own vehicles to passengers. These regulations often require compliance with rules such as background checks, vehicle inspections, accessible vehicle standards, driver and consumer safety measures, insurance provisions, driver training, and driver conduct. While the context does not explicitly mention these regulatory requirements under the risk factors section, it highlights that these are significant complexities for Uber's business due to the adoption of various TNC regulations in different jurisdictions.
# > Evaluation for input Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?
# : score=10 is_done=True reasoning="The latest thoughts and actions are correctly focusing on the key risk factors identified in Uber's 10-K filing. The response directly addresses the query by highlighting important factors such as driver misclassification challenges, operating expenses, user base maintenance, safety risks, new investments, and regulatory conditions. This information is essential for investors considering an investment in Uber."
#
# > Evaluation for input Given the risk factors Uber described in their 10K files, what are the most important factors to consider for investing in Uber?
# : score=7 is_done=False reasoning="The conversation has gathered a comprehensive list of potential risks and challenges related to investing in Uber from their 10-K filing. The latest action is focused on finding specific risks related to rider and driver safety, which are crucial for the investor's consideration. However, the response provided does not directly address these specific risk factors but instead discusses regulatory requirements. Although this information is valuable, it doesn't pinpoint the exact safety concerns as initially mentioned in the earlier thoughts."
#
# > Found solution node: Based on the 2021 10-K filing, some of the most important risk factors for investing in Uber include:
#
# - The potential impact of Driver misclassification challenges: If Drivers were classified as employees or quasi-employees instead of independent contractors, it could significantly affect Uber's financial statements and operations.
# - Increased operating expenses that may not be offset by corresponding increases in revenue.
# - Challenges in maintaining a critical mass of users across various categories such as Drivers, consumers, merchants, shippers, and carriers. Losing any one group could diminish the overall appeal of the platform.
# - Risks associated with criminal activities or negative safety incidents involving platform users, which can harm Uber's brand and reputation.
# - The inherent risks involved in new investments and technological advancements where expected benefits might not materialize.
# - Economic, social, weather, and regulatory conditions that may negatively impact operations in large metropolitan areas.
#
# These factors highlight the operational, financial, and reputational challenges that could affect Uber's business performance and profitability.
# > Got final response: Based on the 2021 10-K filing, some of the most important risk factors for investing in Uber include:
#
# - The potential impact of Driver misclassification challenges: If Drivers were classified as employees or quasi-employees instead of independent contractors, it could significantly affect Uber's financial statements and operations.
# - Increased operating expenses that may not be offset by corresponding increases in revenue.
# - Challenges in maintaining a critical mass of users across various categories such as Drivers, consumers, merchants, shippers, and carriers. Losing any one group could diminish the overall appeal of the platform.
# - Risks associated with criminal activities or negative safety incidents involving platform users, which can harm Uber's brand and reputation.
# - The inherent risks involved in new investments and technological advancements where expected benefits might not materialize.
# - Economic, social, weather, and regulatory conditions that may negatively impact operations in large metropolitan areas.
#
# These factors highlight the operational, financial, and reputational challenges that could affect Uber's business performance and profitability.

# %%
print(str(response))
# Out:
# Based on the 2021 10-K filing, some of the most important risk factors for investing in Uber include:
#
# - The potential impact of Driver misclassification challenges: If Drivers were classified as employees or quasi-employees instead of independent contractors, it could significantly affect Uber's financial statements and operations.
# - Increased operating expenses that may not be offset by corresponding increases in revenue.
# - Challenges in maintaining a critical mass of users across various categories such as Drivers, consumers, merchants, shippers, and carriers. Losing any one group could diminish the overall appeal of the platform.
# - Risks associated with criminal activities or negative safety incidents involving platform users, which can harm Uber's brand and reputation.
# - The inherent risks involved in new investments and technological advancements where expected benefits might not materialize.
# - Economic, social, weather, and regulatory conditions that may negatively impact operations in large metropolitan areas.
#
# These factors highlight the operational, financial, and reputational challenges that could affect Uber's business performance and profitability.

# %%
# agent.reset()

# response = agent.chat("Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.")
# Out:
# > Selecting node to expand: Observation: Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# > Got candidates: ['Analyze the latest quarterly reports for both companies to extract their respective revenue growth rates.', 'Compare the current market valuation and stock performance of Uber and Lyft based on recent financial data.']
# === Calling Function ===
# Calling function: lyft_10k with args: {"input": "Provide the latest quarterly report for Lyft's revenue growth rate."}
# === Calling Function ===
# Calling function: lyft_10k with args: {"input": "Provide detailed revenue growth and risk factors for 2021."}
# === Function Output ===
# Based on the provided context, there isn't a direct mention of Lyft's specific revenue growth rate for any quarter. However, it does discuss that Revenue per Active Rider reached an all-time high in the three months ended December 31, 2021, compared to September 30, 2021. This indicates a positive revenue trend, but the exact growth rate is not specified in the given information.
#
# For more precise quarterly revenue growth rates, one would need to refer to the detailed financial reports or notes provided within the document for specific numerical values.
# === Function Output ===
# Revenue Growth in 2021:
# - Revenue increased by $843.6 million, or 36%, from 2020 to 2021.
# - This growth was primarily driven by a significant increase in the number of Active Riders due to widespread vaccine distribution and community reopenings.
# - Additionally, revenue benefited from licensing and data access agreements that began in the second quarter of 2021.
#
# Risk Factors for 2021:
# - The company's limited operating history and evolving business make it challenging to accurately evaluate future prospects and potential risks.
# - The ability to forecast revenue and manage expenses effectively is a critical factor.
# - Attracting new qualified drivers and riders while retaining existing ones in a cost-effective manner remains a significant challenge.
# - Compliance with laws and regulations applicable to the ridesharing industry poses ongoing risks.
# - Managing platform operations during the COVID-19 pandemic, including travel bans, restrictions, shelter-in-place orders, maintaining demand, and ensuring rider safety, adds complexity.
# - Planning for and managing capital expenditures for current and future offerings is complex due to the evolving nature of the business.
# - Developing, manufacturing, deploying, and maintaining assets like vehicles, technology, and facilities require significant attention.
# - Anticipating and responding to macroeconomic changes and market shifts is crucial but challenging.
# - Maintaining brand value and effectively managing growth while navigating the impacts of the pandemic are ongoing concerns.
# - Expanding geographic reach presents both opportunities and risks.
# - Talent acquisition, integration, and retention at all organizational levels remain key areas for focus.
# - Successfully developing new platform features can enhance user experience but also comes with inherent challenges.
# - Right-sizing the real estate portfolio to align with business needs is an ongoing task.
#
# These factors highlight the dynamic nature of Lyft's operations and the multifaceted risks associated with its evolving business model.
# > Generated new reasoning step: Thought: I need to compare the revenue growth rates of Uber and Lyft from their latest quarterly reports. To do this, I will use the tools provided to fetch the relevant information.
# Action: lyft_10k
# Action Input: {'input': "Provide the latest quarterly report for Lyft's revenue growth rate."}
# Observation: Based on the provided context, there isn't a direct mention of Lyft's specific revenue growth rate for any quarter. However, it does discuss that Revenue per Active Rider reached an all-time high in the three months ended December 31, 2021, compared to September 30, 2021. This indicates a positive revenue trend, but the exact growth rate is not specified in the given information.
#
# For more precise quarterly revenue growth rates, one would need to refer to the detailed financial reports or notes provided within the document for specific numerical values.
# > Generated new reasoning step: Thought: I need to gather financial information about both companies for a comprehensive comparison.
# Action: lyft_10k
# Action Input: {'input': 'Provide detailed revenue growth and risk factors for 2021.'}
# Observation: Revenue Growth in 2021:
# - Revenue increased by $843.6 million, or 36%, from 2020 to 2021.
# - This growth was primarily driven by a significant increase in the number of Active Riders due to widespread vaccine distribution and community reopenings.
# - Additionally, revenue benefited from licensing and data access agreements that began in the second quarter of 2021.
#
# Risk Factors for 2021:
# - The company's limited operating history and evolving business make it challenging to accurately evaluate future prospects and potential risks.
# - The ability to forecast revenue and manage expenses effectively is a critical factor.
# - Attracting new qualified drivers and riders while retaining existing ones in a cost-effective manner remains a significant challenge.
# - Compliance with laws and regulations applicable to the ridesharing industry poses ongoing risks.
# - Managing platform operations during the COVID-19 pandemic, including travel bans, restrictions, shelter-in-place orders, maintaining demand, and ensuring rider safety, adds complexity.
# - Planning for and managing capital expenditures for current and future offerings is complex due to the evolving nature of the business.
# - Developing, manufacturing, deploying, and maintaining assets like vehicles, technology, and facilities require significant attention.
# - Anticipating and responding to macroeconomic changes and market shifts is crucial but challenging.
# - Maintaining brand value and effectively managing growth while navigating the impacts of the pandemic are ongoing concerns.
# - Expanding geographic reach presents both opportunities and risks.
# - Talent acquisition, integration, and retention at all organizational levels remain key areas for focus.
# - Successfully developing new platform features can enhance user experience but also comes with inherent challenges.
# - Right-sizing the real estate portfolio to align with business needs is an ongoing task.
#
# These factors highlight the dynamic nature of Lyft's operations and the multifaceted risks associated with its evolving business model.
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=7 is_done=False reasoning='The latest thought and action are correct in terms of focusing on the revenue growth rates from the latest quarterly reports. However, the observation does not provide concrete numbers as requested in the query. The analysis so far is accurate but lacks specific quantitative data to make a definitive comparison between Uber and Lyft.'
#
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=7 is_done=False reasoning="The latest thought and action are focused on gathering detailed revenue growth and risk factors for 2021, which is a relevant step towards comparing the performance of Uber and Lyft. However, more financial data such as market valuation and stock performance need to be collected to provide a comprehensive comparison. The observation provided offers valuable insights into Lyft's performance but does not yet directly answer the question of which company is performing better based on concrete numbers."
#
# > Got final response: I am still thinking.
# > Selecting node to expand: Observation: Based on the provided context, there isn't a direct mention of Lyft's specific revenue growth rate for any quarter. However, it does discuss that Revenue per Active Rider reached an all-time high in the three months ended December 31, 2021, compared to September 30, 2021. This indicates a positive revenue trend, but the exact growth rate is not specified in the given information.
#
# For more precise quarterly revenue growth rates, one would need to refer to the detailed financial reports or notes provided within the document for specific numerical values.
# > Got candidates: ['ubers_10k']
# > Generated new reasoning step: Thought: (Implicit) I can answer without any more tools!
# Answer: Action: uber_10k
# Action Input: {"input": "Provide the latest quarterly report for Uber's revenue growth rate."}
# > Generated new reasoning step: Thought: (Implicit) I can answer without any more tools!
# Answer: Action: uber_10k
# Action Input: {"input": "Provide the latest quarterly report for Uber's revenue growth rate."}
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=5 is_done=False reasoning="The thought and actions so far are on the right track by trying to compare the revenue growth rates of both companies. However, they have only obtained information for Lyft's revenue trend without a specific numerical value. Additionally, there is no action taken yet to fetch Uber's quarterly report."
#
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=5 is_done=False reasoning='The conversation has not yet gathered enough specific numerical data to make a definitive comparison between Uber and Lyft. The latest quarterly reports are needed for both companies to extract their respective revenue growth rates, but the provided actions only returned partial information. Additionally, there is no explicit mention of how to handle or compare the different growth metrics.'
#
# > Got final response: I am still thinking.
# > Selecting node to expand: Observation: Revenue Growth in 2021:
# - Revenue increased by $843.6 million, or 36%, from 2020 to 2021.
# - This growth was primarily driven by a significant increase in the number of Active Riders due to widespread vaccine distribution and community reopenings.
# - Additionally, revenue benefited from licensing and data access agreements that began in the second quarter of 2021.
#
# Risk Factors for 2021:
# - The company's limited operating history and evolving business make it challenging to accurately evaluate future prospects and potential risks.
# - The ability to forecast revenue and manage expenses effectively is a critical factor.
# - Attracting new qualified drivers and riders while retaining existing ones in a cost-effective manner remains a significant challenge.
# - Compliance with laws and regulations applicable to the ridesharing industry poses ongoing risks.
# - Managing platform operations during the COVID-19 pandemic, including travel bans, restrictions, shelter-in-place orders, maintaining demand, and ensuring rider safety, adds complexity.
# - Planning for and managing capital expenditures for current and future offerings is complex due to the evolving nature of the business.
# - Developing, manufacturing, deploying, and maintaining assets like vehicles, technology, and facilities require significant attention.
# - Anticipating and responding to macroeconomic changes and market shifts is crucial but challenging.
# - Maintaining brand value and effectively managing growth while navigating the impacts of the pandemic are ongoing concerns.
# - Expanding geographic reach presents both opportunities and risks.
# - Talent acquisition, integration, and retention at all organizational levels remain key areas for focus.
# - Successfully developing new platform features can enhance user experience but also comes with inherent challenges.
# - Right-sizing the real estate portfolio to align with business needs is an ongoing task.
#
# These factors highlight the dynamic nature of Lyft's operations and the multifaceted risks associated with its evolving business model.
# > Got candidates: ['lyft_10k']
# === Calling Function ===
# Calling function: uber_10k with args: {"input": "Provide detailed revenue growth and risk factors for 2021."}
# === Function Output ===
# In 2021, Uber reported a significant decrease in All Other revenue compared to the same period in 2020. Specifically, there was a $127 million decline, marking a 94% reduction. However, this segment's adjusted EBITDA loss improved by $450 million, representing a 98% improvement. The favorable impact of selling the ATG Business in the first quarter and divesting JUMP in the second quarter of 2020 were key factors contributing to these changes.
#
# Regarding Freight revenue, it saw an increase largely due to the acquisition of Transplace in the fourth quarter of 2021. This was supplemented by growth in both shippers and carriers on the network, along with a rise in volumes from top shippers. The adjusted EBITDA loss for this segment improved primarily because of a $135 million improvement in gross profit due to increased load margins, though this was partially offset by higher employee headcount costs.
#
# For revenue growth and risk factors, it's important to note that non-GAAP financial measures like Adjusted EBITDA are used but come with limitations and should be reconciled with GAAP financial measures as detailed in the relevant sections of their reports. Additionally, while these segments showed specific improvements or reductions, broader risks such as market competition, regulatory changes, and global economic conditions could impact future performance.
# > Generated new reasoning step: Thought: (Implicit) I can answer without any more tools!
# Answer: Action: uber_10k
# Action Input: {"input": "Provide detailed revenue growth and risk factors for 2021."}
# > Generated new reasoning step: Thought: I need to gather financial information about Uber for a fair comparison.
# Action: uber_10k
# Action Input: {'input': 'Provide detailed revenue growth and risk factors for 2021.'}
# Observation: In 2021, Uber reported a significant decrease in All Other revenue compared to the same period in 2020. Specifically, there was a $127 million decline, marking a 94% reduction. However, this segment's adjusted EBITDA loss improved by $450 million, representing a 98% improvement. The favorable impact of selling the ATG Business in the first quarter and divesting JUMP in the second quarter of 2020 were key factors contributing to these changes.
#
# Regarding Freight revenue, it saw an increase largely due to the acquisition of Transplace in the fourth quarter of 2021. This was supplemented by growth in both shippers and carriers on the network, along with a rise in volumes from top shippers. The adjusted EBITDA loss for this segment improved primarily because of a $135 million improvement in gross profit due to increased load margins, though this was partially offset by higher employee headcount costs.
#
# For revenue growth and risk factors, it's important to note that non-GAAP financial measures like Adjusted EBITDA are used but come with limitations and should be reconciled with GAAP financial measures as detailed in the relevant sections of their reports. Additionally, while these segments showed specific improvements or reductions, broader risks such as market competition, regulatory changes, and global economic conditions could impact future performance.
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=8 is_done=False reasoning="The latest thoughts and actions are on the right track. The user is gathering detailed financial data for both companies, which will help in making a comparative analysis. However, the observations so far have not directly compared the two companies' performance based on concrete numbers as requested in the query."
#
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=4 is_done=False reasoning="The latest thoughts and actions have not provided a comparison between Uber and Lyft's financial performance. The conversation so far focuses on the details of Lyft's revenue growth and risk factors for 2021 without mentioning or comparing Uber's data. To correctly answer the query, we need to gather similar information about Uber as well."
#
# > Got final response: I am still thinking.
# > Selecting node to expand: Observation: In 2021, Uber reported a significant decrease in All Other revenue compared to the same period in 2020. Specifically, there was a $127 million decline, marking a 94% reduction. However, this segment's adjusted EBITDA loss improved by $450 million, representing a 98% improvement. The favorable impact of selling the ATG Business in the first quarter and divesting JUMP in the second quarter of 2020 were key factors contributing to these changes.
#
# Regarding Freight revenue, it saw an increase largely due to the acquisition of Transplace in the fourth quarter of 2021. This was supplemented by growth in both shippers and carriers on the network, along with a rise in volumes from top shippers. The adjusted EBITDA loss for this segment improved primarily because of a $135 million improvement in gross profit due to increased load margins, though this was partially offset by higher employee headcount costs.
#
# For revenue growth and risk factors, it's important to note that non-GAAP financial measures like Adjusted EBITDA are used but come with limitations and should be reconciled with GAAP financial measures as detailed in the relevant sections of their reports. Additionally, while these segments showed specific improvements or reductions, broader risks such as market competition, regulatory changes, and global economic conditions could impact future performance.
# > Got candidates: ['Compare the revenue growth details between Uber and Lyft for a direct comparison.', "Analyze the risk factors mentioned in both companies' 10-K reports to identify commonalities and differences."]
# === Calling Function ===
# Calling function: lyft_10k with args: {"input": "Provide detailed revenue growth and risk factors for 2021."}
# === Calling Function ===
# Calling function: lyft_10k with args: {"input": "Provide detailed market valuation and stock performance data for 2021."}
# === Function Output ===
# Based on the provided context, here is the detailed market valuation and stock performance data as of December 31, 2021:
#
# - **Aggregate Market Value**: The aggregate market value of Lyft's Class A common stock held by non-affiliates was $19.6 billion on June 30, 2021.
#
# - **Stock Performance**:
#   - **Class A Common Stock**: This stock is traded on the Nasdaq Global Select Market under the symbol "LYFT." The stock began trading in March 2019 with an IPO offering price of $72.00 per share and a closing price on March 28, 2019, which was the first day it started trading.
#   - **Performance Graph**: The graph compares the cumulative total stockholder return on Lyft's Class A common stock with the S&P 500 Index and the S&P 500 Information Technology Index. It assumes an investment of $100 at the market close on March 28, 2019.
#
# - **Dividend Policy**: The company has never paid cash dividends and does not anticipate paying any in the foreseeable future.
#
# This data provides insights into Lyft's stock market valuation and performance as of a specific date.
# === Function Output ===
# Revenue Growth in 2021:
# - Revenue increased by $843.6 million, or 36%, from $2,364,681 thousand in 2020 to $3,208,323 thousand in 2021.
# - This growth was primarily driven by the significant increase in the number of Active Riders, which benefited from more widespread vaccine distribution and community reopenings. Additionally, there was an increase in ride frequency as well as a shift towards higher revenue rides such as airport rides.
#
# Risk Factors for 2021:
# - Limited Operating History: The company’s evolving business since its launches in 2012 makes it challenging to forecast future prospects.
# - Economic and Operational Challenges: Risks associated with macroeconomic changes, compliance with laws and regulations, managing expenses during the COVID-19 pandemic, and maintaining platform demand and rider safety.
# - Business Expansion: Difficulty in attracting new drivers and riders and retaining existing ones in a cost-effective manner. Also, challenges related to developing new services and managing capital expenditures for current and future offerings.
# - Supply Chain and Asset Management: Need to effectively manage the deployment and maintenance of assets like vehicles and technology infrastructure.
# - Regulatory Compliance: The necessity to comply with evolving laws and regulations that can affect the business model.
# - Reputation and Brand Maintenance: Ensuring the value of the reputation and brand, especially in light of the pandemic's impact on public perception.
# - Growth Management: Successfully managing growth while addressing the impacts of the pandemic.
# - Geographic Expansion: Difficulty in expanding the geographic reach effectively.
# - Talent Acquisition and Retention: Hiring, integrating, and retaining talented people across all levels of the organization.
# - Technological Development: Challenges in developing, manufacturing, sourcing, deploying, maintaining, and ensuring the utilization of various assets including vehicles, technology, and other services.
# > Generated new reasoning step: Thought: I have gathered both companies' financial data and now need to analyze it.
# Action: lyft_10k
# Action Input: {'input': 'Provide detailed revenue growth and risk factors for 2021.'}
# Observation: Revenue Growth in 2021:
# - Revenue increased by $843.6 million, or 36%, from $2,364,681 thousand in 2020 to $3,208,323 thousand in 2021.
# - This growth was primarily driven by the significant increase in the number of Active Riders, which benefited from more widespread vaccine distribution and community reopenings. Additionally, there was an increase in ride frequency as well as a shift towards higher revenue rides such as airport rides.
#
# Risk Factors for 2021:
# - Limited Operating History: The company’s evolving business since its launches in 2012 makes it challenging to forecast future prospects.
# - Economic and Operational Challenges: Risks associated with macroeconomic changes, compliance with laws and regulations, managing expenses during the COVID-19 pandemic, and maintaining platform demand and rider safety.
# - Business Expansion: Difficulty in attracting new drivers and riders and retaining existing ones in a cost-effective manner. Also, challenges related to developing new services and managing capital expenditures for current and future offerings.
# - Supply Chain and Asset Management: Need to effectively manage the deployment and maintenance of assets like vehicles and technology infrastructure.
# - Regulatory Compliance: The necessity to comply with evolving laws and regulations that can affect the business model.
# - Reputation and Brand Maintenance: Ensuring the value of the reputation and brand, especially in light of the pandemic's impact on public perception.
# - Growth Management: Successfully managing growth while addressing the impacts of the pandemic.
# - Geographic Expansion: Difficulty in expanding the geographic reach effectively.
# - Talent Acquisition and Retention: Hiring, integrating, and retaining talented people across all levels of the organization.
# - Technological Development: Challenges in developing, manufacturing, sourcing, deploying, maintaining, and ensuring the utilization of various assets including vehicles, technology, and other services.
# > Generated new reasoning step: Thought: I have gathered relevant information about both Uber and Lyft's financials for 2021. Now I need to analyze their revenue growth, market valuation, and stock performance.
# Action: lyft_10k
# Action Input: {'input': 'Provide detailed market valuation and stock performance data for 2021.'}
# Observation: Based on the provided context, here is the detailed market valuation and stock performance data as of December 31, 2021:
#
# - **Aggregate Market Value**: The aggregate market value of Lyft's Class A common stock held by non-affiliates was $19.6 billion on June 30, 2021.
#
# - **Stock Performance**:
#   - **Class A Common Stock**: This stock is traded on the Nasdaq Global Select Market under the symbol "LYFT." The stock began trading in March 2019 with an IPO offering price of $72.00 per share and a closing price on March 28, 2019, which was the first day it started trading.
#   - **Performance Graph**: The graph compares the cumulative total stockholder return on Lyft's Class A common stock with the S&P 500 Index and the S&P 500 Information Technology Index. It assumes an investment of $100 at the market close on March 28, 2019.
#
# - **Dividend Policy**: The company has never paid cash dividends and does not anticipate paying any in the foreseeable future.
#
# This data provides insights into Lyft's stock market valuation and performance as of a specific date.
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=7 is_done=False reasoning='The latest thought and action are on the right track by focusing on analyzing the revenue growth and risk factors. However, there is no concrete comparison between Uber and Lyft yet. The observations provide detailed financial information for both companies but fail to draw a direct comparison that addresses which company is performing better based on the given query.'
#
# > Evaluation for input Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.
# : score=7 is_done=False reasoning='The latest thought and action are focused on gathering comprehensive financial data for both Uber and Lyft. The observations provided include detailed revenue growth numbers and risk factors for 2021. However, the conversation has not yet directly compared these metrics to determine which company is performing better based on concrete numbers as requested in the query. Therefore, while the information gathered is relevant and accurate, it has not been used to make a direct comparison.'
#
# > Got final response: I am still thinking.
# > Selecting node to expand: Observation: Revenue Growth in 2021:
# - Revenue increased by $843.6 million, or 36%, from $2,364,681 thousand in 2020 to $3,208,323 thousand in 2021.
# - This growth was primarily driven by the significant increase in the number of Active Riders, which benefited from more widespread vaccine distribution and community reopenings. Additionally, there was an increase in ride frequency as well as a shift towards higher revenue rides such as airport rides.
#
# Risk Factors for 2021:
# - Limited Operating History: The company’s evolving business since its launches in 2012 makes it challenging to forecast future prospects.
# - Economic and Operational Challenges: Risks associated with macroeconomic changes, compliance with laws and regulations, managing expenses during the COVID-19 pandemic, and maintaining platform demand and rider safety.
# - Business Expansion: Difficulty in attracting new drivers and riders and retaining existing ones in a cost-effective manner. Also, challenges related to developing new services and managing capital expenditures for current and future offerings.
# - Supply Chain and Asset Management: Need to effectively manage the deployment and maintenance of assets like vehicles and technology infrastructure.
# - Regulatory Compliance: The necessity to comply with evolving laws and regulations that can affect the business model.
# - Reputation and Brand Maintenance: Ensuring the value of the reputation and brand, especially in light of the pandemic's impact on public perception.
# - Growth Management: Successfully managing growth while addressing the impacts of the pandemic.
# - Geographic Expansion: Difficulty in expanding the geographic reach effectively.
# - Talent Acquisition and Retention: Hiring, integrating, and retaining talented people across all levels of the organization.
# - Technological Development: Challenges in developing, manufacturing, sourcing, deploying, maintaining, and ensuring the utilization of various assets including vehicles, technology, and other services.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 agent.reset()
# ----> 3 response = agent.chat("Given the revenue growth and risk factors of Uber and Lyft, which company is performing better? Please use concrete numbers to inform your decision.")
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/agent/runner/base.py:647, in AgentRunner.chat(self, message, chat_history, tool_choice)
#     642     tool_choice = self.default_tool_choice
#     643 with self.callback_manager.event(
#     644     CBEventType.AGENT_STEP,
#     645     payload={EventPayload.MESSAGES: [message]},
#     646 ) as e:
# --> 647     chat_response = self._chat(
#     648         message=message,
#     649         chat_history=chat_history,
#     650         tool_choice=tool_choice,
#     651         mode=ChatResponseMode.WAIT,
#     652     )
#     653     assert isinstance(chat_response, AgentChatResponse)
#     654     e.on_end(payload={EventPayload.RESPONSE: chat_response})
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/agent/runner/base.py:579, in AgentRunner._chat(self, message, chat_history, tool_choice, mode)
#     576 dispatcher.event(AgentChatWithStepStartEvent(user_msg=message))
#     577 while True:
#     578     # pass step queue in as argument, assume step executor is stateless
# --> 579     cur_step_output = self._run_step(
#     580         task.task_id, mode=mode, tool_choice=tool_choice
#     581     )
#     583     if cur_step_output.is_last:
#     584         result_output = cur_step_output
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/agent/runner/base.py:412, in AgentRunner._run_step(self, task_id, step, input, mode, **kwargs)
#     408 # TODO: figure out if you can dynamically swap in different step executors
#     409 # not clear when you would do that by theoretically possible
#     411 if mode == ChatResponseMode.WAIT:
# --> 412     cur_step_output = self.agent_worker.run_step(step, task, **kwargs)
#     413 elif mode == ChatResponseMode.STREAM:
#     414     cur_step_output = self.agent_worker.stream_step(step, task, **kwargs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/agent/custom/simple.py:210, in CustomSimpleAgentWorker.run_step(self, step, task, **kwargs)
#     207 @trace_method("run_step")
#     208 def run_step(self, step: TaskStep, task: Task, **kwargs: Any) -> TaskStepOutput:
#     209     """Run step."""
# --> 210     agent_response, is_done = self._run_step(
#     211         step.step_state, task, input=step.input
#     212     )
#     213     response = self._get_task_step_response(agent_response, step, is_done)
#     214     # sync step state with task state
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/agent/lats/step.py:222, in LATSAgentWorker._run_step(self, state, task, input)
#     213 def _run_step(
#     214     self, state: Dict[str, Any], task: Task, input: Optional[str] = None
#     215 ) -> Tuple[AgentChatResponse, bool]:
#     216     """Run step.
#     217
#     218     Returns:
#     219         Tuple of (agent_response, is_done)
#     220
#     221     """
# --> 222     return asyncio.run(self._arun_step(state, task, input))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/agent/lats/step.py:241, in LATSAgentWorker._arun_step(self, state, task, input)
#     236     print_text(
#     237         f"> Selecting node to expand: {cur_node.answer}\n", color="green"
#     238     )
#     240 # expand the given node, generate n candidate nodes
# --> 241 new_candidates = await self._get_next_candidates(
#     242     cur_node,
#     243     task.input,
#     244 )
#     246 new_nodes = []
#     247 for candidate in new_candidates:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/agent/lats/step.py:175, in LATSAgentWorker._get_next_candidates(self, cur_node, input)
#     172 # get candidates
#     173 history_str = "\n".join([s.get_content() for s in cur_node.current_reasoning])
# --> 175 candidates = await self.llm.astructured_predict(
#     176     Candidates,
#     177     prompt=self.candiate_expansion_prompt,
#     178     query=input,
#     179     conversation_history=history_str,
#     180     num_candidates=self.num_expansions,
#     181 )
#     182 candidate_strs = candidates.candidates[: self.num_expansions]
#     183 if self.verbose:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:297, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     289 self.span_enter(
#     290     id_=id_,
#     291     bound_args=bound_args,
#    (...)
#     294     tags=tags,
#     295 )
#     296 try:
# --> 297     result = await func(*args, **kwargs)
#     298 except BaseException as e:
#     299     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/llms/llm.py:417, in LLM.astructured_predict(self, output_cls, prompt, **prompt_args)
#     404 dispatcher.event(
#     405     LLMStructuredPredictStartEvent(
#     406         output_cls=output_cls, template=prompt, template_args=prompt_args
#     407     )
#     408 )
#     410 program = get_program_for_llm(
#     411     output_cls,
#     412     prompt,
#     413     self,
#     414     pydantic_program_mode=self.pydantic_program_mode,
#     415 )
# --> 417 result = await program.acall(**prompt_args)
#     418 dispatcher.event(LLMStructuredPredictEndEvent(output=result))
#     419 return result
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/program/function_program.py:223, in FunctionCallingProgram.acall(self, llm_kwargs, *args, **kwargs)
#     220 llm_kwargs = llm_kwargs or {}
#     221 tool = _get_function_tool(self._output_cls)
# --> 223 agent_response = await self._llm.apredict_and_call(
#     224     [tool],
#     225     chat_history=self._prompt.format_messages(llm=self._llm, **kwargs),
#     226     verbose=self._verbose,
#     227     allow_parallel_tool_calls=self._allow_parallel_tool_calls,
#     228     **llm_kwargs,
#     229 )
#     230 return _parse_tool_outputs(
#     231     agent_response,
#     232     allow_parallel_tool_calls=self._allow_parallel_tool_calls,
#     233 )
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:297, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     289 self.span_enter(
#     290     id_=id_,
#     291     bound_args=bound_args,
#    (...)
#     294     tags=tags,
#     295 )
#     296 try:
# --> 297     result = await func(*args, **kwargs)
#     298 except BaseException as e:
#     299     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/core/llms/function_calling.py:247, in FunctionCallingLLM.apredict_and_call(self, tools, user_msg, chat_history, verbose, allow_parallel_tool_calls, error_on_no_tool_call, **kwargs)
#     231     return await super().apredict_and_call(
#     232         tools,
#     233         user_msg=user_msg,
#    (...)
#     236         **kwargs,
#     237     )
#     239 response = await self.achat_with_tools(
#     240     tools,
#     241     user_msg=user_msg,
#    (...)
#     245     **kwargs,
#     246 )
# --> 247 tool_calls = self.get_tool_calls_from_response(
#     248     response, error_on_no_tool_call=error_on_no_tool_call
#     249 )
#     250 tool_tasks = [
#     251     acall_tool_with_selection(tool_call, tools, verbose=verbose)
#     252     for tool_call in tool_calls
#     253 ]
#     254 tool_outputs = await asyncio.gather(*tool_tasks)
#
# File ~/miniconda3/envs/llamaindex/lib/python3.11/site-packages/llama_index/llms/ollama/base.py:248, in Ollama.get_tool_calls_from_response(self, response, error_on_no_tool_call)
#     246 if len(tool_calls) < 1:
#     247     if error_on_no_tool_call:
# --> 248         raise ValueError(
#     249             f"Expected at least one tool call, but got {len(tool_calls)} tool calls."
#     250         )
#     251     else:
#     252         return []
#
# ValueError: Expected at least one tool call, but got 0 tool calls.
